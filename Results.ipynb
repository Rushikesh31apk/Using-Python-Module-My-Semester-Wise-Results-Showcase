# %%
import matplotlib.pyplot as p
x=[33,26,30,27,32,25,29,28,30,34,33,27]
item=['C Prog','DBMS','C-lab','M1','M2','M1-lab','Ele1','Ele2','Ele1-lab', 'Stat1','Stat2','Stat-Lab']
p.title("My First Semester Result")
print('SGPA=9.11')
p.pie(x,labels=item,autopct='%0.1f%%',colors=['pink','g','r','m','pink','y','r','blue','g','pink','pink','y'],startangle=90,explode=[0.1,0.01,0.01,0.01,0.1,0.01,0.01,0.01,0.01,0.1,0.1,0.01],shadow=True)
p.show()
# Out:
# SGPA=9.11

# %%
import matplotlib.pyplot as p
x=[32,33,30,31,32,32,31,32,30,35,34,33]
item=['Adv C Prog','RDBMS','C-lab','M1','M2','M1-lab','Ele1','Ele2','Ele1-lab', 'Stat1','Stat2','Stat-Lab']
p.title("My Second Semester Result")
print('SGPA=9.66')
p.pie(x,labels=item,autopct='%1.00f%%',colors=['pink','m','r','pink','g','y','r','blue','g','m','m','m'],startangle=60,explode=[0.01,0.1,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.1,0.1,0.1],shadow=True)
p.show()
# Out:
# SGPA=9.66

# %%
import matplotlib.pyplot as p
x=[33,26,34,26,26,29,34,22,24,25,30]
item=['DSA','Soft-Engg','DSA-lab','M1','M2','Python-lab','Ele1','Ele2','Ele1-lab', 'Eng','EVS']
p.title("My Third Semester Result")
print('SGPA=9.00')
p.pie(x,labels=item,autopct='%0.1f%%',colors=['m','g','r','pink','y','m','r','blue','pink','g','y'],startangle=300,explode=[0.01,0.01,0.1,0.01,0.01,0.01,0.1,0.01,0.01,0.01,0.01],shadow=True)
p.show()
# Out:
# SGPA=9.00
